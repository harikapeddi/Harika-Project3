# %%
# Dependencies and set up
import pandas as pd
import numpy as np
import json

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
# Raw crime table
table = pd.read_csv('../../Crimes_-_2001_to_Present.csv')
table
# Out:
#                ID Case Number                    Date                  Block  \
# 0        10224738    HY411648  09/05/2015 01:30:00 PM        043XX S WOOD ST
# 1        10224739    HY411615  09/04/2015 11:30:00 AM    008XX N CENTRAL AVE
# 2        11646166    JC213529  09/01/2018 12:01:00 AM  082XX S INGLESIDE AVE
# 3        10224740    HY411595  09/05/2015 12:45:00 PM      035XX W BARRY AVE
# 4        10224741    HY411610  09/05/2015 01:00:00 PM    0000X N LARAMIE AVE
# ...           ...         ...                     ...                    ...
# 7373711  12438635    JE319437  07/29/2021 11:45:00 PM    003XX E RANDOLPH ST
# 7373712  12437903    JE319203  07/29/2021 10:39:00 PM      046XX N MARINE DR
# 7373713  12443891    JE300684  07/13/2021 11:40:00 PM      058XX S THROOP ST
# 7373714  12437612    JE318886  07/29/2021 05:13:00 PM  106XX S CHAMPLAIN AVE
# 7373715  12437228    JE318434  07/29/2021 08:56:00 AM    068XX S SANGAMON ST
#
#          IUCR Primary Type              Description  \
# 0        0486      BATTERY  DOMESTIC BATTERY SIMPLE
# 1        0870        THEFT           POCKET-PICKING
# 2        0810        THEFT                OVER $500
# 3        2023    NARCOTICS    POSS: HEROIN(BRN/TAN)
# 4        0560      ASSAULT                   SIMPLE
# ...       ...          ...                      ...
# 7373711  0870        THEFT           POCKET-PICKING
# 7373712  0486      BATTERY  DOMESTIC BATTERY SIMPLE
# 7373713  031A      ROBBERY          ARMED - HANDGUN
# 7373714  0560      ASSAULT                   SIMPLE
# 7373715  0560      ASSAULT                   SIMPLE
#
#                            Location Description  Arrest  Domestic  ...  Ward  \
# 0                                     RESIDENCE   False      True  ...  12.0
# 1                                       CTA BUS   False     False  ...  29.0
# 2                                     RESIDENCE   False      True  ...   8.0
# 3                                      SIDEWALK    True     False  ...  35.0
# 4                                     APARTMENT   False      True  ...  28.0
# ...                                         ...     ...       ...  ...   ...
# 7373711                           PARK PROPERTY   False     False  ...  42.0
# 7373712  PARKING LOT / GARAGE (NON RESIDENTIAL)   False      True  ...  46.0
# 7373713                                SIDEWALK   False     False  ...  16.0
# 7373714                               APARTMENT   False     False  ...   9.0
# 7373715                               APARTMENT   False     False  ...   6.0
#
#          Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 0                  61.0       08B     1165074.0    1875917.0  2015
# 1                  25.0        06     1138875.0    1904869.0  2015
# 2                  44.0        06           NaN          NaN  2018
# 3                  21.0        18     1152037.0    1920384.0  2015
# 4                  25.0       08A     1141706.0    1900086.0  2015
# ...                 ...       ...           ...          ...   ...
# 7373711            32.0        06     1178911.0    1901260.0  2021
# 7373712             3.0       08B     1170399.0    1931093.0  2021
# 7373713            67.0        03           NaN          NaN  2021
# 7373714            50.0       08A     1182494.0    1834426.0  2021
# 7373715            68.0       08A     1171158.0    1859468.0  2021
#
#                      Updated On   Latitude  Longitude  \
# 0        02/10/2018 03:50:01 PM  41.815117 -87.670000
# 1        02/10/2018 03:50:01 PM  41.895080 -87.765400
# 2        04/06/2019 04:04:43 PM        NaN        NaN
# 3        02/10/2018 03:50:01 PM  41.937406 -87.716650
# 4        02/10/2018 03:50:01 PM  41.881903 -87.755121
# ...                         ...        ...        ...
# 7373711  08/05/2021 05:07:13 PM  41.884356 -87.618470
# 7373712  08/05/2021 05:07:13 PM  41.966409 -87.648852
# 7373713  08/05/2021 05:07:13 PM        NaN        NaN
# 7373714  08/05/2021 05:07:13 PM  41.700875 -87.607385
# 7373715  08/05/2021 05:07:13 PM  41.769848 -87.648163
#
#                               Location
# 0        (41.815117282, -87.669999562)
# 1        (41.895080471, -87.765400451)
# 2                                  NaN
# 3        (41.937405765, -87.716649687)
# 4        (41.881903443, -87.755121152)
# ...                                ...
# 7373711  (41.884355847, -87.618469791)
# 7373712  (41.966409353, -87.648852157)
# 7373713                            NaN
# 7373714  (41.700874918, -87.607385165)
# 7373715  (41.769848355, -87.648163447)
#
# [7373716 rows x 22 columns]

# %%
# Groupby Primary type
df = table.groupby(['Primary Type']).count()['Description']
df
# Out:
# Primary Type
# ARSON                                  12455
# ASSAULT                               471100
# BATTERY                              1351865
# BURGLARY                              411104
# CONCEALED CARRY LICENSE VIOLATION        767
# CRIM SEXUAL ASSAULT                    27865
# CRIMINAL DAMAGE                       840459
# CRIMINAL SEXUAL ASSAULT                 3502
# CRIMINAL TRESPASS                     207073
# DECEPTIVE PRACTICE                    315462
# DOMESTIC VIOLENCE                          1
# GAMBLING                               14602
# HOMICIDE                               11281
# HUMAN TRAFFICKING                         73
# INTERFERENCE WITH PUBLIC OFFICER       17681
# INTIMIDATION                            4351
# KIDNAPPING                              7031
# LIQUOR LAW VIOLATION                   14530
# MOTOR VEHICLE THEFT                   339804
# NARCOTICS                             738658
# NON - CRIMINAL                            38
# NON-CRIMINAL                             175
# NON-CRIMINAL (SUBJECT SPECIFIED)           9
# OBSCENITY                                738
# OFFENSE INVOLVING CHILDREN             51779
# OTHER NARCOTIC VIOLATION                 140
# OTHER OFFENSE                         458537
# PROSTITUTION                           69422
# PUBLIC INDECENCY                         187
# PUBLIC PEACE VIOLATION                 51115
# RITUALISM                                 24
# ROBBERY                               276724
# SEX OFFENSE                            28404
# STALKING                                4040
# THEFT                                1551303
# WEAPONS VIOLATION                      91417
# Name: Description, dtype: int64

# %%
# Groupby Primary type, year and arrest
df = table.groupby(['Year', 'Primary Type', 'Arrest']).count()['ID']
df
# Out:
# Year  Primary Type       Arrest
# 2001  ARSON              False       829
#                          True        181
#       ASSAULT            False     24234
#                          True       7150
#       BATTERY            False     72986
#                                    ...
# 2021  STALKING           True         11
#       THEFT              False     19305
#                          True        842
#       WEAPONS VIOLATION  False      1844
#                          True       3420
# Name: ID, Length: 1244, dtype: int64

# %%
# Groupby Primary type, year and arrest and count be case number
df = table.groupby(['Year', 'Primary Type', 'Arrest']).count()['Case Number']
df
# Out:
# Year  Primary Type       Arrest
# 2001  ARSON              False       829
#                          True        181
#       ASSAULT            False     24234
#                          True       7150
#       BATTERY            False     72986
#                                    ...
# 2021  STALKING           True         11
#       THEFT              False     19305
#                          True        842
#       WEAPONS VIOLATION  False      1844
#                          True       3420
# Name: Case Number, Length: 1244, dtype: int64

# %%
# Groupby Primary type and ID
df = table.groupby(['Primary Type', 'Arrest']).count()['ID']
df
# Out:
# Primary Type       Arrest
# ARSON              False       10885
#                    True         1570
# ASSAULT            False      366741
#                    True       104359
# BATTERY            False     1049158
#                               ...
# STALKING           True          611
# THEFT              False     1371119
#                    True       180184
# WEAPONS VIOLATION  False       21590
#                    True        69827
# Name: ID, Length: 71, dtype: int64

# %%
len(df)
# Out:
# 71

# %%
# Defining table type
table['Date'].dtypes
# Out:
# dtype('O')

# %%
# Crime column type
print (table.dtypes)
# Out:
# ID                        int64
# Case Number              object
# Date                     object
# Block                    object
# IUCR                     object
# Primary Type             object
# Description              object
# Location Description     object
# Arrest                     bool
# Domestic                   bool
# Beat                      int64
# District                float64
# Ward                    float64
# Community Area          float64
# FBI Code                 object
# X Coordinate            float64
# Y Coordinate            float64
# Year                      int64
# Updated On               object
# Latitude                float64
# Longitude               float64
# Location                 object
# dtype: object

# %%
# Dropping table
table = table.drop(columns=['Case Number', 'Location', 'Updated On', 'Block', 'Community Area', 'Beat', 'District', 'Ward', 'FBI Code', 'X Coordinate', 'Y Coordinate' ])
table
# Out:
#                ID                    Date  IUCR Primary Type  \
# 0        10224738  09/05/2015 01:30:00 PM  0486      BATTERY
# 1        10224739  09/04/2015 11:30:00 AM  0870        THEFT
# 2        11646166  09/01/2018 12:01:00 AM  0810        THEFT
# 3        10224740  09/05/2015 12:45:00 PM  2023    NARCOTICS
# 4        10224741  09/05/2015 01:00:00 PM  0560      ASSAULT
# ...           ...                     ...   ...          ...
# 7373711  12438635  07/29/2021 11:45:00 PM  0870        THEFT
# 7373712  12437903  07/29/2021 10:39:00 PM  0486      BATTERY
# 7373713  12443891  07/13/2021 11:40:00 PM  031A      ROBBERY
# 7373714  12437612  07/29/2021 05:13:00 PM  0560      ASSAULT
# 7373715  12437228  07/29/2021 08:56:00 AM  0560      ASSAULT
#
#                      Description                    Location Description  \
# 0        DOMESTIC BATTERY SIMPLE                               RESIDENCE
# 1                 POCKET-PICKING                                 CTA BUS
# 2                      OVER $500                               RESIDENCE
# 3          POSS: HEROIN(BRN/TAN)                                SIDEWALK
# 4                         SIMPLE                               APARTMENT
# ...                          ...                                     ...
# 7373711           POCKET-PICKING                           PARK PROPERTY
# 7373712  DOMESTIC BATTERY SIMPLE  PARKING LOT / GARAGE (NON RESIDENTIAL)
# 7373713          ARMED - HANDGUN                                SIDEWALK
# 7373714                   SIMPLE                               APARTMENT
# 7373715                   SIMPLE                               APARTMENT
#
#          Arrest  Domestic  Year   Latitude  Longitude
# 0         False      True  2015  41.815117 -87.670000
# 1         False     False  2015  41.895080 -87.765400
# 2         False      True  2018        NaN        NaN
# 3          True     False  2015  41.937406 -87.716650
# 4         False      True  2015  41.881903 -87.755121
# ...         ...       ...   ...        ...        ...
# 7373711   False     False  2021  41.884356 -87.618470
# 7373712   False      True  2021  41.966409 -87.648852
# 7373713   False     False  2021        NaN        NaN
# 7373714   False     False  2021  41.700875 -87.607385
# 7373715   False     False  2021  41.769848 -87.648163
#
# [7373716 rows x 11 columns]

# %%
# Dropping NAN from latitude
table = table[table['Latitude'].notna()]
table
# Out:
#                ID                    Date  IUCR Primary Type  \
# 0        10224738  09/05/2015 01:30:00 PM  0486      BATTERY
# 1        10224739  09/04/2015 11:30:00 AM  0870        THEFT
# 3        10224740  09/05/2015 12:45:00 PM  2023    NARCOTICS
# 4        10224741  09/05/2015 01:00:00 PM  0560      ASSAULT
# 5        10224742  09/05/2015 10:55:00 AM  0610     BURGLARY
# ...           ...                     ...   ...          ...
# 7373710  12442317  07/29/2021 08:00:00 PM  0870        THEFT
# 7373711  12438635  07/29/2021 11:45:00 PM  0870        THEFT
# 7373712  12437903  07/29/2021 10:39:00 PM  0486      BATTERY
# 7373714  12437612  07/29/2021 05:13:00 PM  0560      ASSAULT
# 7373715  12437228  07/29/2021 08:56:00 AM  0560      ASSAULT
#
#                      Description                    Location Description  \
# 0        DOMESTIC BATTERY SIMPLE                               RESIDENCE
# 1                 POCKET-PICKING                                 CTA BUS
# 3          POSS: HEROIN(BRN/TAN)                                SIDEWALK
# 4                         SIMPLE                               APARTMENT
# 5                 FORCIBLE ENTRY                               RESIDENCE
# ...                          ...                                     ...
# 7373710           POCKET-PICKING                           PARK PROPERTY
# 7373711           POCKET-PICKING                           PARK PROPERTY
# 7373712  DOMESTIC BATTERY SIMPLE  PARKING LOT / GARAGE (NON RESIDENTIAL)
# 7373714                   SIMPLE                               APARTMENT
# 7373715                   SIMPLE                               APARTMENT
#
#          Arrest  Domestic  Year   Latitude  Longitude
# 0         False      True  2015  41.815117 -87.670000
# 1         False     False  2015  41.895080 -87.765400
# 3          True     False  2015  41.937406 -87.716650
# 4         False      True  2015  41.881903 -87.755121
# 5         False     False  2015  41.744379 -87.658431
# ...         ...       ...   ...        ...        ...
# 7373710   False     False  2021  41.884335 -87.619164
# 7373711   False     False  2021  41.884356 -87.618470
# 7373712   False      True  2021  41.966409 -87.648852
# 7373714   False     False  2021  41.700875 -87.607385
# 7373715   False     False  2021  41.769848 -87.648163
#
# [7300102 rows x 11 columns]

# %%
table.reset_index(drop=True)
# Out:
#                ID                    Date  IUCR Primary Type  \
# 0        10224738  09/05/2015 01:30:00 PM  0486      BATTERY
# 1        10224739  09/04/2015 11:30:00 AM  0870        THEFT
# 2        10224740  09/05/2015 12:45:00 PM  2023    NARCOTICS
# 3        10224741  09/05/2015 01:00:00 PM  0560      ASSAULT
# 4        10224742  09/05/2015 10:55:00 AM  0610     BURGLARY
# ...           ...                     ...   ...          ...
# 7300097  12442317  07/29/2021 08:00:00 PM  0870        THEFT
# 7300098  12438635  07/29/2021 11:45:00 PM  0870        THEFT
# 7300099  12437903  07/29/2021 10:39:00 PM  0486      BATTERY
# 7300100  12437612  07/29/2021 05:13:00 PM  0560      ASSAULT
# 7300101  12437228  07/29/2021 08:56:00 AM  0560      ASSAULT
#
#                      Description                    Location Description  \
# 0        DOMESTIC BATTERY SIMPLE                               RESIDENCE
# 1                 POCKET-PICKING                                 CTA BUS
# 2          POSS: HEROIN(BRN/TAN)                                SIDEWALK
# 3                         SIMPLE                               APARTMENT
# 4                 FORCIBLE ENTRY                               RESIDENCE
# ...                          ...                                     ...
# 7300097           POCKET-PICKING                           PARK PROPERTY
# 7300098           POCKET-PICKING                           PARK PROPERTY
# 7300099  DOMESTIC BATTERY SIMPLE  PARKING LOT / GARAGE (NON RESIDENTIAL)
# 7300100                   SIMPLE                               APARTMENT
# 7300101                   SIMPLE                               APARTMENT
#
#          Arrest  Domestic  Year   Latitude  Longitude
# 0         False      True  2015  41.815117 -87.670000
# 1         False     False  2015  41.895080 -87.765400
# 2          True     False  2015  41.937406 -87.716650
# 3         False      True  2015  41.881903 -87.755121
# 4         False     False  2015  41.744379 -87.658431
# ...         ...       ...   ...        ...        ...
# 7300097   False     False  2021  41.884335 -87.619164
# 7300098   False     False  2021  41.884356 -87.618470
# 7300099   False      True  2021  41.966409 -87.648852
# 7300100   False     False  2021  41.700875 -87.607385
# 7300101   False     False  2021  41.769848 -87.648163
#
# [7300102 rows x 11 columns]

# %%
# Groupby by ID
table_2 = table.groupby(['Year', 'Primary Type', 'Arrest']).count()['ID']
table_2
# Out:
# Year  Primary Type       Arrest
# 2001  ARSON              False       824
#                          True        180
#       ASSAULT            False     24142
#                          True       7118
#       BATTERY            False     72665
#                                    ...
# 2021  STALKING           True         11
#       THEFT              False     18797
#                          True        842
#       WEAPONS VIOLATION  False      1844
#                          True       3419
# Name: ID, Length: 1239, dtype: int64

# %%
print (table.dtypes)
# Out:
# ID                        int64
# Date                     object
# IUCR                     object
# Primary Type             object
# Description              object
# Location Description     object
# Arrest                     bool
# Domestic                   bool
# Year                      int64
# Latitude                float64
# Longitude               float64
# dtype: object

# %%
rds_connection_string = "postgres:postgres@localhost:5432/Project_03"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine,reflect=True)
Base
# Out:
# sqlalchemy.ext.automap.Base

# %%
engine.table_names()
# Out:
# ['Chicago_crime']

# %%
table.to_sql(name='Chicago_crime', con=engine, if_exists='append', index=False)

# %%
from sqlalchemy import inspect

# %%
inspector = inspect(engine)
inspector.get_columns('Chicago_crime')
# Out:
# [{'name': 'ID',
#   'type': INTEGER(),
#   'nullable': False,
#   'default': 'nextval(\'"Chicago_crime_ID_seq"\'::regclass)',
#   'autoincrement': True,
#   'comment': None},
#  {'name': 'Date',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'IUCR',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Primary Type',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Description',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Location Description',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Arrest',
#   'type': BOOLEAN(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Domestic',
#   'type': BOOLEAN(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Year',
#   'type': INTEGER(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Latitude',
#   'type': DOUBLE_PRECISION(precision=53),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Longitude',
#   'type': DOUBLE_PRECISION(precision=53),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None}]
